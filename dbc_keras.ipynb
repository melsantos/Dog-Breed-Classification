# %% [markdown]
# Importing modules needed to run program

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import pandas as pd
import scipy.misc
from scipy.stats import itemfreq
from statsmodels.tools import categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions, ResNet50
from os import listdir, getcwd
from os.path import isfile, join, dirname, abspath
import pickle
import time
from datetime import timedelta
from zipfile import ZipFile
from io import BytesIO
import PIL.Image
from IPython.display import display

# %% [markdown]
# Linking Google Drive with Collab

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
#      |████████████████████████████████| 993kB 3.4MB/s
#   Building wheel for PyDrive (setup.py) ... done

# %% [markdown]
# Downloading labels.csv, train.zip, and test.zip.

# %%
link = 'https://drive.google.com/open?id=1lhUvUznD_r1dTGv7wZI_RNH18HOyd8yv'
fluff, id = link.split('=')
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('labels.csv') 

link = 'https://drive.google.com/open?id=1poX95lT6DrIH3GnAshcmATD3cMfynfa5'
fluff, id = link.split('=')
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('train.zip')

link = 'https://drive.google.com/open?id=1tqFoSKWqiqq_-LMeWqbvOcHJKzdty5X1'
fluff, id = link.split('=')
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('test.zip')

# %% [markdown]
# Declaring standard variables. We have to manually calculate the number of epochs so that we run roughly the number of iterations we did in the TensorFlow implementation.
#
# The TensorFlow implementation runs for 3500 iterations with a batch size of 50 each time. The size of the test data is 645. 645 / 50 ≈ 13. So it takes 13 iterations to fully traverse the dataset. 3500 / 13 ≈ **270 epochs**.

# %%
img_size = 60
batch_size = 50
epochs = 270 # Check note above.

filter_size1 = 5        
num_filters1 = 32       

filter_size2 = 4         
num_filters2 = 64 

filter_size3 = 3
num_filters3 = 128

Nber_of_breeds = 8

# %% [markdown]
# Function needed for turning the training and test zip files into a pickle

# %%
def DataBase_creator(archivezip, nwidth, nheight, save_name):
    start_time = time.time()
    
    s = (len(archivezip.namelist()[:])-1, nwidth, nheight,3)
    allImage = np.zeros(s)

    for i in range(1,len(archivezip.namelist()[:])):
        filename = BytesIO(archivezip.read(archivezip.namelist()[i]))
        image = PIL.Image.open(filename) # open colour image
        image = image.resize((nwidth, nheight))
        image = np.array(image)
        image = np.clip(image/255.0, 0.0, 1.0)

        allImage[i-1]=image
    
    pickle.dump(allImage, open( save_name + '.p', "wb" ) )
    
    end_time = time.time()
    time_dif = end_time - start_time
    print("Time usage: " + str(timedelta(seconds=int(round(time_dif)))))

# %% [markdown]
# Function for selecting N numbered dog breeds from dataset

# %%
def main_breeds(labels_raw, Nber_breeds , all_breeds='TRUE'):
    labels_freq_pd = itemfreq(labels_raw["breed"])
    labels_freq_pd = labels_freq_pd[labels_freq_pd[:, 1].argsort()[::-1]] #[::-1] ==> to sort in descending order
    
    if all_breeds == 'FALSE':
        main_labels = labels_freq_pd[:,0][0:Nber_breeds]
    else: 
        main_labels = labels_freq_pd[:,0][:]
        
    labels_raw_np = labels_raw["breed"].as_matrix() #transform in numpy
    labels_raw_np = labels_raw_np.reshape(labels_raw_np.shape[0],1)

    labels_filtered_index = np.where(labels_raw_np == main_labels)

    return labels_filtered_index

# %% [markdown]
# Unzipping the zipfile

# %%
archive_train = ZipFile("train.zip", 'r')
archive_test = ZipFile("test.zip", 'r')
archive_train.namelist()[0:5]
len(archive_train.namelist()[:])-1
# Out:
# 10222

# %% [markdown]
# Creating the pickle files

# %%
DataBase_creator(archive_train, img_size, img_size , "train")
DataBase_creator(archive_test, img_size, img_size , "test")
# Out:
# Time usage: 0:00:48
# Time usage: 0:00:48

# %% [markdown]
# Load the pickle files

# %%
train = pickle.load( open( "train.p", "rb" ) )
test = pickle.load(open( "test.p", "rb" ))
print(train.shape)
print(test.shape)
# Out:
# (10222, 60, 60, 3)
# (10357, 60, 60, 3)

# %% [markdown]
# Label preparation

# %%
labels_raw = pd.read_csv('labels.csv')
labels_filtered_index = main_breeds(labels_raw = labels_raw, Nber_breeds = Nber_of_breeds, all_breeds='FALSE')
labels_filtered = labels_raw.iloc[labels_filtered_index[0],:]
train_filtered = train[labels_filtered_index[0],:,:,:]

print('- Number of images remaining after selecting the {0} main breeds : {1}'.format(Nber_of_breeds, labels_filtered_index[0].shape))
print('- The shape of train_filtered dataset is : {0}'.format(train_filtered.shape))
for breed in labels_filtered.breed.unique():
  print("{0}".format(breed))

labels = np.asarray(labels_filtered["breed"])    
labels = pd.Series(labels, dtype="category")
labels = labels.cat.codes
# Out:
# - Number of images remaining after selecting the 8 main breeds : (922,)
# - The shape of train_filtered dataset is : (922, 60, 60, 3)
# scottish_deerhound
# maltese_dog
# shih-tzu
# entlebucher
# bernese_mountain_dog
# afghan_hound
# great_pyrenees
# pomeranian
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Split filtered data into train and test

# %%
num_validation = 0.30
X_train, X_validation, y_train, y_validation = train_test_split(train_filtered, labels, test_size=num_validation, random_state=6)
print(X_train.shape)
# Out:
# (645, 60, 60, 3)

# %% [markdown]
# Define model layers

# %%
model = keras.Sequential([
        # Convolutional layer 1
        keras.layers.Conv2D(num_filters1,
                            kernel_size=filter_size1,
                            padding='same',
                            activation='relu',
                            use_bias=True,
                            input_shape=[img_size, img_size, 3]),
        keras.layers.MaxPooling2D(pool_size=2,
                                  padding='same'),
        
        # Convolutional layer 2
        keras.layers.Conv2D(num_filters2,
                            kernel_size=filter_size2,
                            padding='same',
                            activation='relu',
                            use_bias=True),
        keras.layers.MaxPooling2D(pool_size=2,
                                  padding='same'),
        
        # Convolutional layer 3
        keras.layers.Conv2D(num_filters3,
                            kernel_size=filter_size3,
                            padding='same',
                            activation='relu',
                            use_bias=True),
        keras.layers.MaxPooling2D(pool_size=2, padding='same'),
        keras.layers.Dropout(0.3),
        
        # Flatten layer
        keras.layers.Flatten(input_shape=(img_size, img_size)),

        # Fully connected layer of 100 nodes
        keras.layers.Dense(500, activation='relu'),
        keras.layers.Dropout(0.4),

        # Fully connected layer of 8 dog breeds
        keras.layers.Dense(8, activation='softmax')
    ])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# Define compile options for model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Train model

# %%
start_time = time.time()
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)
end_time = time.time()
time_dif = end_time - start_time
print("Time usage: " + str(timedelta(seconds=int(round(time_dif)))))
# Out:
# Epoch 1/270
# 645/645 [==============================] - 4s 6ms/sample - loss: 2.1355 - acc: 0.1116
# Epoch 2/270
# 645/645 [==============================] - 0s 293us/sample - loss: 2.0547 - acc: 0.1597
# Epoch 3/270
# 645/645 [==============================] - 0s 293us/sample - loss: 1.9386 - acc: 0.2450
# Epoch 4/270
# 645/645 [==============================] - 0s 291us/sample - loss: 1.7035 - acc: 0.3674
# Epoch 5/270
# 645/645 [==============================] - 0s 289us/sample - loss: 1.5841 - acc: 0.3783
# Epoch 6/270
# 645/645 [==============================] - 0s 288us/sample - loss: 1.4092 - acc: 0.4884
# Epoch 7/270
# 645/645 [==============================] - 0s 297us/sample - loss: 1.2986 - acc: 0.5380
# Epoch 8/270
# 645/645 [==============================] - 0s 299us/sample - loss: 1.1363 - acc: 0.5907
# Epoch 9/270
# 645/645 [==============================] - 0s 291us/sample - loss: 1.0194 - acc: 0.6527
# Epoch 10/270
# 645/645 [==============================] - 0s 293us/sample - loss: 0.8685 - acc: 0.6853
# Epoch 11/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.7726 - acc: 0.7519
# Epoch 12/270
# 645/645 [==============================] - 0s 298us/sample - loss: 0.6328 - acc: 0.7736
# Epoch 13/270
# 645/645 [==============================] - 0s 311us/sample - loss: 0.5029 - acc: 0.8248
# Epoch 14/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.4822 - acc: 0.8217
# Epoch 15/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.3363 - acc: 0.8930
# Epoch 16/270
# 645/645 [==============================] - 0s 296us/sample - loss: 0.2840 - acc: 0.8899
# Epoch 17/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.2506 - acc: 0.9240
# Epoch 18/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.2132 - acc: 0.9225
# Epoch 19/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.2665 - acc: 0.9039
# Epoch 20/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.2181 - acc: 0.9318
# Epoch 21/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.1465 - acc: 0.9535
# Epoch 22/270
# 645/645 [==============================] - 0s 293us/sample - loss: 0.0972 - acc: 0.9721
# Epoch 23/270
# 645/645 [==============================] - 0s 306us/sample - loss: 0.0792 - acc: 0.9829
# Epoch 24/270
# 645/645 [==============================] - 0s 305us/sample - loss: 0.0581 - acc: 0.9891
# Epoch 25/270
# 645/645 [==============================] - 0s 292us/sample - loss: 0.0687 - acc: 0.9767
# Epoch 26/270
# 645/645 [==============================] - 0s 302us/sample - loss: 0.0651 - acc: 0.9829
# Epoch 27/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0418 - acc: 0.9953
# Epoch 28/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0475 - acc: 0.9829
# Epoch 29/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0551 - acc: 0.9814
# Epoch 30/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0333 - acc: 0.9922
# Epoch 31/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0408 - acc: 0.9891
# Epoch 32/270
# 645/645 [==============================] - 0s 276us/sample - loss: 0.0365 - acc: 0.9891
# Epoch 33/270
# 645/645 [==============================] - 0s 277us/sample - loss: 0.0466 - acc: 0.9860
# Epoch 34/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0463 - acc: 0.9860
# Epoch 35/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0279 - acc: 0.9907
# Epoch 36/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0334 - acc: 0.9891
# Epoch 37/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0256 - acc: 0.9922
# Epoch 38/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0336 - acc: 0.9907
# Epoch 39/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0647 - acc: 0.9752
# Epoch 40/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0452 - acc: 0.9829
# Epoch 41/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0598 - acc: 0.9829
# Epoch 42/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0625 - acc: 0.9845
# Epoch 43/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0509 - acc: 0.9845
# Epoch 44/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0279 - acc: 0.9922
# Epoch 45/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0340 - acc: 0.9891
# Epoch 46/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0317 - acc: 0.9907
# Epoch 47/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0169 - acc: 0.9953
# Epoch 48/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0111 - acc: 0.9969
# Epoch 49/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0121 - acc: 0.9984
# Epoch 50/270
# 645/645 [==============================] - 0s 299us/sample - loss: 0.0206 - acc: 0.9938
# Epoch 51/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0177 - acc: 0.9953
# Epoch 52/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0087 - acc: 0.9984
# Epoch 53/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0153 - acc: 0.9969
# Epoch 54/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0067 - acc: 0.9984
# Epoch 55/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0160 - acc: 0.9969
# Epoch 56/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0090 - acc: 0.9969
# Epoch 57/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0072 - acc: 0.9984
# Epoch 58/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0195 - acc: 0.9938
# Epoch 59/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0356 - acc: 0.9922
# Epoch 60/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0226 - acc: 0.9907
# Epoch 61/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0248 - acc: 0.9938
# Epoch 62/270
# 645/645 [==============================] - 0s 277us/sample - loss: 0.0187 - acc: 0.9969
# Epoch 63/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0349 - acc: 0.9876
# Epoch 64/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0297 - acc: 0.9922
# Epoch 65/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0317 - acc: 0.9922
# Epoch 66/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0167 - acc: 0.9953
# Epoch 67/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0073 - acc: 0.9969
# Epoch 68/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0137 - acc: 0.9938
# Epoch 69/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0494 - acc: 0.9876
# Epoch 70/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0784 - acc: 0.9705
# Epoch 71/270
# 645/645 [==============================] - 0s 299us/sample - loss: 0.0753 - acc: 0.9783
# Epoch 72/270
# 645/645 [==============================] - 0s 303us/sample - loss: 0.0532 - acc: 0.9814
# Epoch 73/270
# 645/645 [==============================] - 0s 296us/sample - loss: 0.0395 - acc: 0.9907
# Epoch 74/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0318 - acc: 0.9938
# Epoch 75/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0186 - acc: 0.9953
# Epoch 76/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0335 - acc: 0.9922
# Epoch 77/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0434 - acc: 0.9876
# Epoch 78/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0341 - acc: 0.9876
# Epoch 79/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0406 - acc: 0.9876
# Epoch 80/270
# 645/645 [==============================] - 0s 277us/sample - loss: 0.0191 - acc: 0.9938
# Epoch 81/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0139 - acc: 0.9938
# Epoch 82/270
# 645/645 [==============================] - 0s 292us/sample - loss: 0.0088 - acc: 0.9984
# Epoch 83/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0073 - acc: 0.9984
# Epoch 84/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0070 - acc: 0.9969
# Epoch 85/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0159 - acc: 0.9953
# Epoch 86/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0083 - acc: 0.9969
# Epoch 87/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0101 - acc: 0.9969
# Epoch 88/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0125 - acc: 0.9938
# Epoch 89/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0129 - acc: 0.9984
# Epoch 90/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0059 - acc: 0.9984
# Epoch 91/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0461 - acc: 0.9907
# Epoch 92/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0151 - acc: 0.9922
# Epoch 93/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0077 - acc: 0.9984
# Epoch 94/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0058 - acc: 0.9984
# Epoch 95/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0066 - acc: 0.9969
# Epoch 96/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0214 - acc: 0.9938
# Epoch 97/270
# 645/645 [==============================] - 0s 277us/sample - loss: 0.0316 - acc: 0.9891
# Epoch 98/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0260 - acc: 0.9953
# Epoch 99/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.0385 - acc: 0.9907
# Epoch 100/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0182 - acc: 0.9953
# Epoch 101/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0205 - acc: 0.9969
# Epoch 102/270
# 645/645 [==============================] - 0s 277us/sample - loss: 0.0138 - acc: 0.9938
# Epoch 103/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0169 - acc: 0.9969
# Epoch 104/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0114 - acc: 0.9984
# Epoch 105/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0074 - acc: 0.9984
# Epoch 106/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0044 - acc: 0.9984
# Epoch 107/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0061 - acc: 0.9984
# Epoch 108/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0069 - acc: 0.9969
# Epoch 109/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0200 - acc: 0.9922
# Epoch 110/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0134 - acc: 0.9938
# Epoch 111/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0040 - acc: 1.0000
# Epoch 112/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0111 - acc: 0.9984
# Epoch 113/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0047 - acc: 0.9984
# Epoch 114/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0083 - acc: 0.9969
# Epoch 115/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.0056 - acc: 0.9984
# Epoch 116/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.0064 - acc: 0.9984
# Epoch 117/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0084 - acc: 0.9969
# Epoch 118/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0173 - acc: 0.9969
# Epoch 119/270
# 645/645 [==============================] - 0s 277us/sample - loss: 0.0349 - acc: 0.9860
# Epoch 120/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.0514 - acc: 0.9845
# Epoch 121/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0606 - acc: 0.9798
# Epoch 122/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0573 - acc: 0.9845
# Epoch 123/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0551 - acc: 0.9845
# Epoch 124/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0481 - acc: 0.9860
# Epoch 125/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0370 - acc: 0.9922
# Epoch 126/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0207 - acc: 0.9953
# Epoch 127/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0353 - acc: 0.9891
# Epoch 128/270
# 645/645 [==============================] - 0s 275us/sample - loss: 0.0221 - acc: 0.9938
# Epoch 129/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0295 - acc: 0.9907
# Epoch 130/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0342 - acc: 0.9891
# Epoch 131/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0338 - acc: 0.9907
# Epoch 132/270
# 645/645 [==============================] - 0s 296us/sample - loss: 0.0166 - acc: 0.9938
# Epoch 133/270
# 645/645 [==============================] - 0s 276us/sample - loss: 0.0235 - acc: 0.9891
# Epoch 134/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0102 - acc: 0.9969
# Epoch 135/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0280 - acc: 0.9938
# Epoch 136/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0460 - acc: 0.9783
# Epoch 137/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0408 - acc: 0.9860
# Epoch 138/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0135 - acc: 0.9953
# Epoch 139/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0030 - acc: 1.0000
# Epoch 140/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0142 - acc: 0.9984
# Epoch 141/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0026 - acc: 1.0000
# Epoch 142/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0040 - acc: 0.9984
# Epoch 143/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0041 - acc: 0.9984
# Epoch 144/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0012 - acc: 1.0000
# Epoch 145/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0019 - acc: 1.0000
# Epoch 146/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0062 - acc: 0.9969
# Epoch 147/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0048 - acc: 0.9984
# Epoch 148/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0160 - acc: 0.9953
# Epoch 149/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0046 - acc: 1.0000
# Epoch 150/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0064 - acc: 0.9969
# Epoch 151/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0016 - acc: 1.0000
# Epoch 152/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0021 - acc: 1.0000
# Epoch 153/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0024 - acc: 0.9984
# Epoch 154/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0012 - acc: 1.0000
# Epoch 155/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0066 - acc: 0.9969
# Epoch 156/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0103 - acc: 0.9969
# Epoch 157/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0086 - acc: 0.9984
# Epoch 158/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0042 - acc: 0.9984
# Epoch 159/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0039 - acc: 0.9984
# Epoch 160/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0050 - acc: 0.9984
# Epoch 161/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0023 - acc: 0.9984
# Epoch 162/270
# 645/645 [==============================] - 0s 276us/sample - loss: 0.0089 - acc: 0.9969
# Epoch 163/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0025 - acc: 1.0000
# Epoch 164/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0021 - acc: 0.9984
# Epoch 165/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0019 - acc: 1.0000
# Epoch 166/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0017 - acc: 1.0000
# Epoch 167/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0033 - acc: 0.9984
# Epoch 168/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0060 - acc: 0.9984
# Epoch 169/270
# 645/645 [==============================] - 0s 276us/sample - loss: 4.9976e-04 - acc: 1.0000
# Epoch 170/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0042 - acc: 0.9969
# Epoch 171/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.0011 - acc: 1.0000
# Epoch 172/270
# 645/645 [==============================] - 0s 293us/sample - loss: 0.0023 - acc: 0.9984
# Epoch 173/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0028 - acc: 0.9984
# Epoch 174/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0049 - acc: 0.9984
# Epoch 175/270
# 645/645 [==============================] - 0s 302us/sample - loss: 0.0174 - acc: 0.9984
# Epoch 176/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0036 - acc: 0.9984
# Epoch 177/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0013 - acc: 1.0000
# Epoch 178/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0025 - acc: 1.0000
# Epoch 179/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0033 - acc: 0.9984
# Epoch 180/270
# 645/645 [==============================] - 0s 292us/sample - loss: 0.0063 - acc: 0.9969
# Epoch 181/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0044 - acc: 0.9984
# Epoch 182/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0132 - acc: 0.9953
# Epoch 183/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.0084 - acc: 0.9984
# Epoch 184/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0374 - acc: 0.9953
# Epoch 185/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0112 - acc: 0.9969
# Epoch 186/270
# 645/645 [==============================] - 0s 292us/sample - loss: 0.0067 - acc: 0.9969
# Epoch 187/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0086 - acc: 0.9984
# Epoch 188/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0037 - acc: 1.0000
# Epoch 189/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0014 - acc: 1.0000
# Epoch 190/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0093 - acc: 0.9969
# Epoch 191/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0121 - acc: 0.9953
# Epoch 192/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0204 - acc: 0.9953
# Epoch 193/270
# 645/645 [==============================] - 0s 289us/sample - loss: 0.0312 - acc: 0.9907
# Epoch 194/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0349 - acc: 0.9860
# Epoch 195/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0461 - acc: 0.9876
# Epoch 196/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0083 - acc: 0.9969
# Epoch 197/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0392 - acc: 0.9922
# Epoch 198/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0660 - acc: 0.9814
# Epoch 199/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0239 - acc: 0.9907
# Epoch 200/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0118 - acc: 0.9938
# Epoch 201/270
# 645/645 [==============================] - 0s 278us/sample - loss: 0.0254 - acc: 0.9891
# Epoch 202/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0306 - acc: 0.9891
# Epoch 203/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0360 - acc: 0.9891
# Epoch 204/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0304 - acc: 0.9922
# Epoch 205/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0184 - acc: 0.9953
# Epoch 206/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0253 - acc: 0.9922
# Epoch 207/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0220 - acc: 0.9953
# Epoch 208/270
# 645/645 [==============================] - 0s 279us/sample - loss: 0.0136 - acc: 0.9953
# Epoch 209/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0060 - acc: 0.9984
# Epoch 210/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0134 - acc: 0.9969
# Epoch 211/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0088 - acc: 0.9984
# Epoch 212/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0020 - acc: 1.0000
# Epoch 213/270
# 645/645 [==============================] - 0s 291us/sample - loss: 0.0044 - acc: 0.9984
# Epoch 214/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0306 - acc: 0.9938
# Epoch 215/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0095 - acc: 0.9969
# Epoch 216/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0060 - acc: 0.9984
# Epoch 217/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0015 - acc: 1.0000
# Epoch 218/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0033 - acc: 0.9984
# Epoch 219/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0014 - acc: 1.0000
# Epoch 220/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0016 - acc: 0.9984
# Epoch 221/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0073 - acc: 0.9953
# Epoch 222/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0011 - acc: 1.0000
# Epoch 223/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0180 - acc: 0.9891
# Epoch 224/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0167 - acc: 0.9953
# Epoch 225/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0042 - acc: 0.9984
# Epoch 226/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0022 - acc: 1.0000
# Epoch 227/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0032 - acc: 1.0000
# Epoch 228/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0105 - acc: 0.9953
# Epoch 229/270
# 645/645 [==============================] - 0s 315us/sample - loss: 0.0055 - acc: 0.9984
# Epoch 230/270
# 645/645 [==============================] - 0s 283us/sample - loss: 0.0194 - acc: 0.9969
# Epoch 231/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0042 - acc: 1.0000
# Epoch 232/270
# 645/645 [==============================] - 0s 293us/sample - loss: 0.0030 - acc: 0.9984
# Epoch 233/270
# 645/645 [==============================] - 0s 293us/sample - loss: 0.0044 - acc: 0.9984
# Epoch 234/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0064 - acc: 0.9969
# Epoch 235/270
# 645/645 [==============================] - 0s 299us/sample - loss: 0.0113 - acc: 0.9953
# Epoch 236/270
# 645/645 [==============================] - 0s 298us/sample - loss: 0.0121 - acc: 0.9969
# Epoch 237/270
# 645/645 [==============================] - 0s 297us/sample - loss: 0.0234 - acc: 0.9969
# Epoch 238/270
# 645/645 [==============================] - 0s 298us/sample - loss: 0.0097 - acc: 0.9984
# Epoch 239/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0317 - acc: 0.9891
# Epoch 240/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0261 - acc: 0.9922
# Epoch 241/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0219 - acc: 0.9922
# Epoch 242/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0357 - acc: 0.9938
# Epoch 243/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0033 - acc: 1.0000
# Epoch 244/270
# 645/645 [==============================] - 0s 281us/sample - loss: 0.0167 - acc: 0.9969
# Epoch 245/270
# 645/645 [==============================] - 0s 303us/sample - loss: 0.0025 - acc: 1.0000
# Epoch 246/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0031 - acc: 0.9984
# Epoch 247/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0099 - acc: 0.9938
# Epoch 248/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0057 - acc: 0.9984
# Epoch 249/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0143 - acc: 0.9984
# Epoch 250/270
# 645/645 [==============================] - 0s 297us/sample - loss: 0.0011 - acc: 1.0000
# Epoch 251/270
# 645/645 [==============================] - 0s 288us/sample - loss: 0.0011 - acc: 1.0000
# Epoch 252/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0052 - acc: 0.9969
# Epoch 253/270
# 645/645 [==============================] - 0s 297us/sample - loss: 0.0048 - acc: 0.9969
# Epoch 254/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0074 - acc: 0.9984
# Epoch 255/270
# 645/645 [==============================] - 0s 293us/sample - loss: 0.0138 - acc: 0.9953
# Epoch 256/270
# 645/645 [==============================] - 0s 303us/sample - loss: 0.0174 - acc: 0.9938
# Epoch 257/270
# 645/645 [==============================] - 0s 303us/sample - loss: 0.0132 - acc: 0.9953
# Epoch 258/270
# 645/645 [==============================] - 0s 310us/sample - loss: 0.0051 - acc: 0.9984
# Epoch 259/270
# 645/645 [==============================] - 0s 295us/sample - loss: 0.0110 - acc: 0.9953
# Epoch 260/270
# 645/645 [==============================] - 0s 280us/sample - loss: 0.0026 - acc: 1.0000
# Epoch 261/270
# 645/645 [==============================] - 0s 294us/sample - loss: 0.0040 - acc: 0.9984
# Epoch 262/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0049 - acc: 0.9969
# Epoch 263/270
# 645/645 [==============================] - 0s 285us/sample - loss: 0.0018 - acc: 1.0000
# Epoch 264/270
# 645/645 [==============================] - 0s 290us/sample - loss: 9.7250e-04 - acc: 1.0000
# Epoch 265/270
# 645/645 [==============================] - 0s 290us/sample - loss: 0.0019 - acc: 1.0000
# Epoch 266/270
# 645/645 [==============================] - 0s 300us/sample - loss: 0.0012 - acc: 1.0000
# Epoch 267/270
# 645/645 [==============================] - 0s 287us/sample - loss: 0.0095 - acc: 0.9984
# Epoch 268/270
# 645/645 [==============================] - 0s 286us/sample - loss: 0.0113 - acc: 0.9969
# Epoch 269/270
# 645/645 [==============================] - 0s 282us/sample - loss: 0.0338 - acc: 0.9953
# Epoch 270/270
# 645/645 [==============================] - 0s 284us/sample - loss: 0.0177 - acc: 0.9953
# Time usage: 0:00:58

# %% [markdown]
# Evaluate model against validation data

# %%
loss, acc = model.evaluate(X_validation, y_validation)
# print("Loss: {0}".format(loss))
# print("Accuracy: {0}".format(acc))
# Out:
# 277/277 [==============================] - 0s 521us/sample - loss: 5.9029 - acc: 0.3538

# %% [markdown]
# Save weights

# %%
model.save_weights('first_try.h5')

# %% [markdown]
# Do some model prediction

# %%
# insert code for prediction
